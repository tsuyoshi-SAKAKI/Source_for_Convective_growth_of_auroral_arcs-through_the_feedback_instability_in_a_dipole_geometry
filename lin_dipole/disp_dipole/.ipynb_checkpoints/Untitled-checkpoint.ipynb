# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
ni = 499
ds_theta0   = np.loadtxt("./l1079_lat2000.d")
dsk_theta0  = ds_theta0[:ni,2]
dsfr_theta0 = ds_theta0[:ni,4]
dsfi_theta0 = ds_theta0[:ni,5]
plt.plot(dsk_theta0,dsfi_theta0)
# plt.xlim(300,2500)
plt.show()

# %%
print(ds_theta0.shape)
ds_theta0 = ds_theta0.reshape(5,ni,6)
print(ds_theta0.shape)
# Out:
# (499, 5, 6)
# (5, 499, 6)

# %%
for i in range(0,5):
    plt.plot(dsk_theta0,ds_theta0[i,:,4])
plt.show()
for i in range(0,5):
    plt.plot(dsk_theta0,ds_theta0[i,:,5])
plt.show()

# %%
plt.plot(dsk_theta0,ds_theta0[0,:,5])
plt.plot(dsk_theta0,dsfi_theta0)

# %%
for k in range(0,499):
    if dsfi_theta0[k] == dsfi_theta0.max() :
        km = dsk_theta0[k]
        print("k, omega =",km, dsfi_theta0[k])
# Out:
# k, omega = 1630.3783 0.0052660953
